# %%
import csv

import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42

# %% [markdown]
# # Specify each path

# %%
# Specify data paths
dataset = 'model/keypoint_classifier/keypoint.csv'
model_save_path = 'model/keypoint_classifier/keypoint_classifier.hdf5'
tflite_save_path = 'model/keypoint_classifier/keypoint_classifier.tflite'

# %% [markdown]
# # Set number of classes

# %%
# Change training classes if necessary
NUM_CLASSES = 2

# %% [markdown]
# # Dataset reading

# %%
X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1)))

# %%
y_dataset = np.loadtxt(dataset, delimiter=',', dtype='int32', usecols=(0))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=RANDOM_SEED)

# %%
# Classes count
counts = np.unique(y_dataset, return_counts=True)
df = pd.DataFrame(counts)
df.T.plot(kind="bar", stacked=True)
print(counts)
# Out:
# (array([0, 1]), array([204, 159], dtype=int64))

# %% [markdown]
# # Model building

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input((21 * 2, )),
    tf.keras.layers.Dropout(0.0),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dropout(0.0),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dropout(0.0),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
])

# %%
model.summary()  # tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout (Dropout)            (None, 42)                0
# _________________________________________________________________
# dense (Dense)                (None, 32)                1376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 34
# =================================================================
# Total params: 2,994
# Trainable params: 2,994
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model checkpoint callback
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False, save_best_only=True)
# Callback for early stopping
es_callback = tf.keras.callbacks.EarlyStopping(patience=50, verbose=1)

# %%
# Model compilation
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # Model training

# %%
model.fit(
    X_train,
    y_train,
    epochs=1000,
    batch_size=64,
    validation_data=(X_test, y_test),
    callbacks=[cp_callback, es_callback]
)
# Out:
# Epoch 1/1000
# 5/5 [==============================] - 1s 139ms/step - loss: 0.6526 - accuracy: 0.6830 - val_loss: 0.5939 - val_accuracy: 1.0000
#
# Epoch 00001: val_loss improved from inf to 0.59385, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 2/1000
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5770 - accuracy: 0.9981 - val_loss: 0.5218 - val_accuracy: 0.9780
#
# Epoch 00002: val_loss improved from 0.59385 to 0.52177, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 3/1000
# 5/5 [==============================] - 0s 29ms/step - loss: 0.5074 - accuracy: 0.9828 - val_loss: 0.4563 - val_accuracy: 1.0000
#
# Epoch 00003: val_loss improved from 0.52177 to 0.45631, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 4/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4436 - accuracy: 1.0000 - val_loss: 0.3857 - val_accuracy: 1.0000
#
# Epoch 00004: val_loss improved from 0.45631 to 0.38569, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 5/1000
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3788 - accuracy: 1.0000 - val_loss: 0.3196 - val_accuracy: 1.0000
#
# Epoch 00005: val_loss improved from 0.38569 to 0.31960, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 6/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3109 - accuracy: 1.0000 - val_loss: 0.2580 - val_accuracy: 1.0000
#
# Epoch 00006: val_loss improved from 0.31960 to 0.25800, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 7/1000
# 5/5 [==============================] - 0s 17ms/step - loss: 0.2545 - accuracy: 1.0000 - val_loss: 0.2022 - val_accuracy: 1.0000
#
# Epoch 00007: val_loss improved from 0.25800 to 0.20222, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 8/1000
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2016 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 1.0000
#
# Epoch 00008: val_loss improved from 0.20222 to 0.15439, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 9/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1486 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 1.0000
#
# Epoch 00009: val_loss improved from 0.15439 to 0.11563, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 10/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1153 - accuracy: 1.0000 - val_loss: 0.0850 - val_accuracy: 1.0000
#
# Epoch 00010: val_loss improved from 0.11563 to 0.08498, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 11/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0824 - accuracy: 1.0000 - val_loss: 0.0621 - val_accuracy: 1.0000
#
# Epoch 00011: val_loss improved from 0.08498 to 0.06212, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 12/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0636 - accuracy: 1.0000 - val_loss: 0.0455 - val_accuracy: 1.0000
#
# Epoch 00012: val_loss improved from 0.06212 to 0.04548, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 13/1000
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0440 - accuracy: 1.0000 - val_loss: 0.0339 - val_accuracy: 1.0000
#
# Epoch 00013: val_loss improved from 0.04548 to 0.03394, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 14/1000
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0355 - accuracy: 1.0000 - val_loss: 0.0259 - val_accuracy: 1.0000
#
# Epoch 00014: val_loss improved from 0.03394 to 0.02591, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 15/1000
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0255 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 1.0000
#
# Epoch 00015: val_loss improved from 0.02591 to 0.02025, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 16/1000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.0160 - val_accuracy: 1.0000
#
# Epoch 00016: val_loss improved from 0.02025 to 0.01597, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 17/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 1.0000
#
# Epoch 00017: val_loss improved from 0.01597 to 0.01292, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 18/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.0107 - val_accuracy: 1.0000
#
# Epoch 00018: val_loss improved from 0.01292 to 0.01070, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 19/1000
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 1.0000
#
# Epoch 00019: val_loss improved from 0.01070 to 0.00901, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 20/1000
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
#
# Epoch 00020: val_loss improved from 0.00901 to 0.00770, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 21/1000
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
#
# Epoch 00021: val_loss improved from 0.00770 to 0.00667, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 22/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000
#
# Epoch 00022: val_loss improved from 0.00667 to 0.00586, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 23/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
#
# Epoch 00023: val_loss improved from 0.00586 to 0.00518, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 24/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
#
# Epoch 00024: val_loss improved from 0.00518 to 0.00461, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 25/1000
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
#
# Epoch 00025: val_loss improved from 0.00461 to 0.00412, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 26/1000
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
#
# Epoch 00026: val_loss improved from 0.00412 to 0.00369, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 27/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
#
# Epoch 00027: val_loss improved from 0.00369 to 0.00328, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 28/1000
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
#
# Epoch 00028: val_loss improved from 0.00328 to 0.00286, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 29/1000
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
#
# Epoch 00029: val_loss improved from 0.00286 to 0.00250, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 30/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
#
# Epoch 00030: val_loss improved from 0.00250 to 0.00220, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 31/1000
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
#
# Epoch 00031: val_loss improved from 0.00220 to 0.00195, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 32/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
#
# Epoch 00032: val_loss improved from 0.00195 to 0.00174, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 33/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
#
# Epoch 00033: val_loss improved from 0.00174 to 0.00156, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 34/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
#
# Epoch 00034: val_loss improved from 0.00156 to 0.00141, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 35/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
#
# Epoch 00035: val_loss improved from 0.00141 to 0.00128, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 36/1000
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
#
# Epoch 00036: val_loss improved from 0.00128 to 0.00117, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 37/1000
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
#
# Epoch 00037: val_loss improved from 0.00117 to 0.00108, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 38/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 9.9141e-04 - val_accuracy: 1.0000
#
# Epoch 00038: val_loss improved from 0.00108 to 0.00099, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 39/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 9.8744e-04 - accuracy: 1.0000 - val_loss: 9.1707e-04 - val_accuracy: 1.0000
#
# Epoch 00039: val_loss improved from 0.00099 to 0.00092, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 40/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 8.8072e-04 - accuracy: 1.0000 - val_loss: 8.5143e-04 - val_accuracy: 1.0000
#
# Epoch 00040: val_loss improved from 0.00092 to 0.00085, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 41/1000
# 5/5 [==============================] - 0s 23ms/step - loss: 8.5186e-04 - accuracy: 1.0000 - val_loss: 7.9383e-04 - val_accuracy: 1.0000
#
# Epoch 00041: val_loss improved from 0.00085 to 0.00079, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 42/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 8.5354e-04 - accuracy: 1.0000 - val_loss: 7.4261e-04 - val_accuracy: 1.0000
#
# Epoch 00042: val_loss improved from 0.00079 to 0.00074, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 43/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 7.5763e-04 - accuracy: 1.0000 - val_loss: 6.9714e-04 - val_accuracy: 1.0000
#
# Epoch 00043: val_loss improved from 0.00074 to 0.00070, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 44/1000
# 5/5 [==============================] - 0s 34ms/step - loss: 7.1112e-04 - accuracy: 1.0000 - val_loss: 6.5632e-04 - val_accuracy: 1.0000
#
# Epoch 00044: val_loss improved from 0.00070 to 0.00066, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 45/1000
# 5/5 [==============================] - 0s 20ms/step - loss: 6.4763e-04 - accuracy: 1.0000 - val_loss: 6.1966e-04 - val_accuracy: 1.0000
#
# Epoch 00045: val_loss improved from 0.00066 to 0.00062, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 46/1000
# 5/5 [==============================] - 0s 17ms/step - loss: 6.0786e-04 - accuracy: 1.0000 - val_loss: 5.8607e-04 - val_accuracy: 1.0000
#
# Epoch 00046: val_loss improved from 0.00062 to 0.00059, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 47/1000
# 5/5 [==============================] - 0s 22ms/step - loss: 5.3497e-04 - accuracy: 1.0000 - val_loss: 5.5554e-04 - val_accuracy: 1.0000
#
# Epoch 00047: val_loss improved from 0.00059 to 0.00056, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 48/1000
# 5/5 [==============================] - 0s 23ms/step - loss: 5.5823e-04 - accuracy: 1.0000 - val_loss: 5.2573e-04 - val_accuracy: 1.0000
#
# Epoch 00048: val_loss improved from 0.00056 to 0.00053, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 49/1000
# 5/5 [==============================] - 0s 33ms/step - loss: 5.5361e-04 - accuracy: 1.0000 - val_loss: 4.9812e-04 - val_accuracy: 1.0000
#
# Epoch 00049: val_loss improved from 0.00053 to 0.00050, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 50/1000
# 5/5 [==============================] - 0s 21ms/step - loss: 4.9017e-04 - accuracy: 1.0000 - val_loss: 4.7292e-04 - val_accuracy: 1.0000
#
# Epoch 00050: val_loss improved from 0.00050 to 0.00047, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 51/1000
# 5/5 [==============================] - 0s 18ms/step - loss: 4.8159e-04 - accuracy: 1.0000 - val_loss: 4.4784e-04 - val_accuracy: 1.0000
#
# Epoch 00051: val_loss improved from 0.00047 to 0.00045, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 52/1000
# 5/5 [==============================] - 0s 15ms/step - loss: 4.2912e-04 - accuracy: 1.0000 - val_loss: 4.2594e-04 - val_accuracy: 1.0000
#
# Epoch 00052: val_loss improved from 0.00045 to 0.00043, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 53/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 4.6183e-04 - accuracy: 1.0000 - val_loss: 4.0566e-04 - val_accuracy: 1.0000
#
# Epoch 00053: val_loss improved from 0.00043 to 0.00041, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 54/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 4.2389e-04 - accuracy: 1.0000 - val_loss: 3.8728e-04 - val_accuracy: 1.0000
#
# Epoch 00054: val_loss improved from 0.00041 to 0.00039, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 55/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 3.8583e-04 - accuracy: 1.0000 - val_loss: 3.7066e-04 - val_accuracy: 1.0000
#
# Epoch 00055: val_loss improved from 0.00039 to 0.00037, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 56/1000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.8643e-04 - accuracy: 1.0000 - val_loss: 3.5524e-04 - val_accuracy: 1.0000
#
# Epoch 00056: val_loss improved from 0.00037 to 0.00036, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 57/1000
# 5/5 [==============================] - 0s 17ms/step - loss: 3.6847e-04 - accuracy: 1.0000 - val_loss: 3.4071e-04 - val_accuracy: 1.0000
#
# Epoch 00057: val_loss improved from 0.00036 to 0.00034, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 58/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 3.8249e-04 - accuracy: 1.0000 - val_loss: 3.2708e-04 - val_accuracy: 1.0000
#
# Epoch 00058: val_loss improved from 0.00034 to 0.00033, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 59/1000
# 5/5 [==============================] - 0s 29ms/step - loss: 3.2305e-04 - accuracy: 1.0000 - val_loss: 3.1444e-04 - val_accuracy: 1.0000
#
# Epoch 00059: val_loss improved from 0.00033 to 0.00031, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 60/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 3.0574e-04 - accuracy: 1.0000 - val_loss: 3.0244e-04 - val_accuracy: 1.0000
#
# Epoch 00060: val_loss improved from 0.00031 to 0.00030, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 61/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 3.2433e-04 - accuracy: 1.0000 - val_loss: 2.9100e-04 - val_accuracy: 1.0000
#
# Epoch 00061: val_loss improved from 0.00030 to 0.00029, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 62/1000
# 5/5 [==============================] - 0s 19ms/step - loss: 2.8751e-04 - accuracy: 1.0000 - val_loss: 2.8039e-04 - val_accuracy: 1.0000
#
# Epoch 00062: val_loss improved from 0.00029 to 0.00028, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 63/1000
# 5/5 [==============================] - 0s 28ms/step - loss: 2.7540e-04 - accuracy: 1.0000 - val_loss: 2.6948e-04 - val_accuracy: 1.0000
#
# Epoch 00063: val_loss improved from 0.00028 to 0.00027, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 64/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 2.7101e-04 - accuracy: 1.0000 - val_loss: 2.5957e-04 - val_accuracy: 1.0000
#
# Epoch 00064: val_loss improved from 0.00027 to 0.00026, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 65/1000
# 5/5 [==============================] - 0s 19ms/step - loss: 2.6053e-04 - accuracy: 1.0000 - val_loss: 2.5019e-04 - val_accuracy: 1.0000
#
# Epoch 00065: val_loss improved from 0.00026 to 0.00025, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 66/1000
# 5/5 [==============================] - 0s 28ms/step - loss: 2.6893e-04 - accuracy: 1.0000 - val_loss: 2.4136e-04 - val_accuracy: 1.0000
#
# Epoch 00066: val_loss improved from 0.00025 to 0.00024, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 67/1000
# 5/5 [==============================] - 0s 28ms/step - loss: 2.3881e-04 - accuracy: 1.0000 - val_loss: 2.3303e-04 - val_accuracy: 1.0000
#
# Epoch 00067: val_loss improved from 0.00024 to 0.00023, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 68/1000
# 5/5 [==============================] - 0s 28ms/step - loss: 2.4648e-04 - accuracy: 1.0000 - val_loss: 2.2509e-04 - val_accuracy: 1.0000
#
# Epoch 00068: val_loss improved from 0.00023 to 0.00023, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 69/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 2.2505e-04 - accuracy: 1.0000 - val_loss: 2.1766e-04 - val_accuracy: 1.0000
#
# Epoch 00069: val_loss improved from 0.00023 to 0.00022, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 70/1000
# 5/5 [==============================] - 0s 30ms/step - loss: 2.1874e-04 - accuracy: 1.0000 - val_loss: 2.1037e-04 - val_accuracy: 1.0000
#
# Epoch 00070: val_loss improved from 0.00022 to 0.00021, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 71/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 2.0271e-04 - accuracy: 1.0000 - val_loss: 2.0333e-04 - val_accuracy: 1.0000
#
# Epoch 00071: val_loss improved from 0.00021 to 0.00020, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 72/1000
# 5/5 [==============================] - 0s 28ms/step - loss: 2.0291e-04 - accuracy: 1.0000 - val_loss: 1.9681e-04 - val_accuracy: 1.0000
#
# Epoch 00072: val_loss improved from 0.00020 to 0.00020, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 73/1000
# 5/5 [==============================] - 0s 23ms/step - loss: 2.0301e-04 - accuracy: 1.0000 - val_loss: 1.9064e-04 - val_accuracy: 1.0000
#
# Epoch 00073: val_loss improved from 0.00020 to 0.00019, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 74/1000
# 5/5 [==============================] - 0s 23ms/step - loss: 1.8822e-04 - accuracy: 1.0000 - val_loss: 1.8489e-04 - val_accuracy: 1.0000
#
# Epoch 00074: val_loss improved from 0.00019 to 0.00018, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 75/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 1.8047e-04 - accuracy: 1.0000 - val_loss: 1.7935e-04 - val_accuracy: 1.0000
#
# Epoch 00075: val_loss improved from 0.00018 to 0.00018, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 76/1000
# 5/5 [==============================] - 0s 16ms/step - loss: 1.7562e-04 - accuracy: 1.0000 - val_loss: 1.7384e-04 - val_accuracy: 1.0000
#
# Epoch 00076: val_loss improved from 0.00018 to 0.00017, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 77/1000
# 5/5 [==============================] - 0s 15ms/step - loss: 1.8061e-04 - accuracy: 1.0000 - val_loss: 1.6850e-04 - val_accuracy: 1.0000
#
# Epoch 00077: val_loss improved from 0.00017 to 0.00017, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 78/1000
# 5/5 [==============================] - 0s 17ms/step - loss: 1.6396e-04 - accuracy: 1.0000 - val_loss: 1.6354e-04 - val_accuracy: 1.0000
#
# Epoch 00078: val_loss improved from 0.00017 to 0.00016, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 79/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 1.6699e-04 - accuracy: 1.0000 - val_loss: 1.5871e-04 - val_accuracy: 1.0000
#
# Epoch 00079: val_loss improved from 0.00016 to 0.00016, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 80/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 1.7270e-04 - accuracy: 1.0000 - val_loss: 1.5410e-04 - val_accuracy: 1.0000
#
# Epoch 00080: val_loss improved from 0.00016 to 0.00015, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 81/1000
# 5/5 [==============================] - 0s 28ms/step - loss: 1.5092e-04 - accuracy: 1.0000 - val_loss: 1.4983e-04 - val_accuracy: 1.0000
#
# Epoch 00081: val_loss improved from 0.00015 to 0.00015, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 82/1000
# 5/5 [==============================] - 0s 19ms/step - loss: 1.5859e-04 - accuracy: 1.0000 - val_loss: 1.4557e-04 - val_accuracy: 1.0000
#
# Epoch 00082: val_loss improved from 0.00015 to 0.00015, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 83/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 1.5267e-04 - accuracy: 1.0000 - val_loss: 1.4157e-04 - val_accuracy: 1.0000
#
# Epoch 00083: val_loss improved from 0.00015 to 0.00014, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 84/1000
# 5/5 [==============================] - 0s 30ms/step - loss: 1.5118e-04 - accuracy: 1.0000 - val_loss: 1.3781e-04 - val_accuracy: 1.0000
#
# Epoch 00084: val_loss improved from 0.00014 to 0.00014, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 85/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 1.3665e-04 - accuracy: 1.0000 - val_loss: 1.3424e-04 - val_accuracy: 1.0000
#
# Epoch 00085: val_loss improved from 0.00014 to 0.00013, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 86/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 1.4714e-04 - accuracy: 1.0000 - val_loss: 1.3078e-04 - val_accuracy: 1.0000
#
# Epoch 00086: val_loss improved from 0.00013 to 0.00013, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 87/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 1.4082e-04 - accuracy: 1.0000 - val_loss: 1.2748e-04 - val_accuracy: 1.0000
#
# Epoch 00087: val_loss improved from 0.00013 to 0.00013, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 88/1000
# 5/5 [==============================] - 0s 21ms/step - loss: 1.3650e-04 - accuracy: 1.0000 - val_loss: 1.2434e-04 - val_accuracy: 1.0000
#
# Epoch 00088: val_loss improved from 0.00013 to 0.00012, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 89/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 1.2190e-04 - accuracy: 1.0000 - val_loss: 1.2137e-04 - val_accuracy: 1.0000
#
# Epoch 00089: val_loss improved from 0.00012 to 0.00012, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 90/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 1.3225e-04 - accuracy: 1.0000 - val_loss: 1.1842e-04 - val_accuracy: 1.0000
#
# Epoch 00090: val_loss improved from 0.00012 to 0.00012, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 91/1000
# 5/5 [==============================] - 0s 29ms/step - loss: 1.2185e-04 - accuracy: 1.0000 - val_loss: 1.1562e-04 - val_accuracy: 1.0000
#
# Epoch 00091: val_loss improved from 0.00012 to 0.00012, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 92/1000
# 5/5 [==============================] - 0s 29ms/step - loss: 1.1099e-04 - accuracy: 1.0000 - val_loss: 1.1297e-04 - val_accuracy: 1.0000
#
# Epoch 00092: val_loss improved from 0.00012 to 0.00011, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 93/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 1.2023e-04 - accuracy: 1.0000 - val_loss: 1.1032e-04 - val_accuracy: 1.0000
#
# Epoch 00093: val_loss improved from 0.00011 to 0.00011, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 94/1000
# 5/5 [==============================] - 0s 29ms/step - loss: 1.2096e-04 - accuracy: 1.0000 - val_loss: 1.0773e-04 - val_accuracy: 1.0000
#
# Epoch 00094: val_loss improved from 0.00011 to 0.00011, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 95/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 1.0720e-04 - accuracy: 1.0000 - val_loss: 1.0528e-04 - val_accuracy: 1.0000
#
# Epoch 00095: val_loss improved from 0.00011 to 0.00011, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 96/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 1.0245e-04 - accuracy: 1.0000 - val_loss: 1.0290e-04 - val_accuracy: 1.0000
#
# Epoch 00096: val_loss improved from 0.00011 to 0.00010, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 97/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 1.0228e-04 - accuracy: 1.0000 - val_loss: 1.0057e-04 - val_accuracy: 1.0000
#
# Epoch 00097: val_loss improved from 0.00010 to 0.00010, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 98/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 1.0074e-04 - accuracy: 1.0000 - val_loss: 9.8255e-05 - val_accuracy: 1.0000
#
# Epoch 00098: val_loss improved from 0.00010 to 0.00010, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 99/1000
# 5/5 [==============================] - 0s 30ms/step - loss: 9.2976e-05 - accuracy: 1.0000 - val_loss: 9.6048e-05 - val_accuracy: 1.0000
#
# Epoch 00099: val_loss improved from 0.00010 to 0.00010, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 100/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 1.0251e-04 - accuracy: 1.0000 - val_loss: 9.3862e-05 - val_accuracy: 1.0000
#
# Epoch 00100: val_loss improved from 0.00010 to 0.00009, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 101/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 9.6991e-05 - accuracy: 1.0000 - val_loss: 9.1785e-05 - val_accuracy: 1.0000
#
# Epoch 00101: val_loss improved from 0.00009 to 0.00009, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 102/1000
# 5/5 [==============================] - 0s 29ms/step - loss: 9.4820e-05 - accuracy: 1.0000 - val_loss: 8.9780e-05 - val_accuracy: 1.0000
#
# Epoch 00102: val_loss improved from 0.00009 to 0.00009, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 103/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 1.0125e-04 - accuracy: 1.0000 - val_loss: 8.7814e-05 - val_accuracy: 1.0000
#
# Epoch 00103: val_loss improved from 0.00009 to 0.00009, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 104/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 9.1471e-05 - accuracy: 1.0000 - val_loss: 8.5935e-05 - val_accuracy: 1.0000
#
# Epoch 00104: val_loss improved from 0.00009 to 0.00009, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 105/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 8.8096e-05 - accuracy: 1.0000 - val_loss: 8.4079e-05 - val_accuracy: 1.0000
#
# Epoch 00105: val_loss improved from 0.00009 to 0.00008, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 106/1000
# 5/5 [==============================] - 0s 23ms/step - loss: 8.5032e-05 - accuracy: 1.0000 - val_loss: 8.2346e-05 - val_accuracy: 1.0000
#
# Epoch 00106: val_loss improved from 0.00008 to 0.00008, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 107/1000
# 5/5 [==============================] - 0s 23ms/step - loss: 8.1412e-05 - accuracy: 1.0000 - val_loss: 8.0665e-05 - val_accuracy: 1.0000
#
# Epoch 00107: val_loss improved from 0.00008 to 0.00008, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 108/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 8.1864e-05 - accuracy: 1.0000 - val_loss: 7.9015e-05 - val_accuracy: 1.0000
#
# Epoch 00108: val_loss improved from 0.00008 to 0.00008, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 109/1000
# 5/5 [==============================] - 0s 21ms/step - loss: 8.5585e-05 - accuracy: 1.0000 - val_loss: 7.7398e-05 - val_accuracy: 1.0000
#
# Epoch 00109: val_loss improved from 0.00008 to 0.00008, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 110/1000
# 5/5 [==============================] - 0s 21ms/step - loss: 7.5781e-05 - accuracy: 1.0000 - val_loss: 7.5867e-05 - val_accuracy: 1.0000
#
# Epoch 00110: val_loss improved from 0.00008 to 0.00008, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 111/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 7.7407e-05 - accuracy: 1.0000 - val_loss: 7.4342e-05 - val_accuracy: 1.0000
#
# Epoch 00111: val_loss improved from 0.00008 to 0.00007, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 112/1000
# 5/5 [==============================] - 0s 22ms/step - loss: 7.6821e-05 - accuracy: 1.0000 - val_loss: 7.2858e-05 - val_accuracy: 1.0000
#
# Epoch 00112: val_loss improved from 0.00007 to 0.00007, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 113/1000
# 5/5 [==============================] - 0s 22ms/step - loss: 7.6409e-05 - accuracy: 1.0000 - val_loss: 7.1458e-05 - val_accuracy: 1.0000
#
# Epoch 00113: val_loss improved from 0.00007 to 0.00007, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 114/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 7.6022e-05 - accuracy: 1.0000 - val_loss: 7.0105e-05 - val_accuracy: 1.0000
#
# Epoch 00114: val_loss improved from 0.00007 to 0.00007, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 115/1000
# 5/5 [==============================] - 0s 22ms/step - loss: 7.1266e-05 - accuracy: 1.0000 - val_loss: 6.8796e-05 - val_accuracy: 1.0000
#
# Epoch 00115: val_loss improved from 0.00007 to 0.00007, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 116/1000
# 5/5 [==============================] - 0s 21ms/step - loss: 6.9356e-05 - accuracy: 1.0000 - val_loss: 6.7511e-05 - val_accuracy: 1.0000
#
# Epoch 00116: val_loss improved from 0.00007 to 0.00007, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 117/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 6.6137e-05 - accuracy: 1.0000 - val_loss: 6.6276e-05 - val_accuracy: 1.0000
#
# Epoch 00117: val_loss improved from 0.00007 to 0.00007, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 118/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 6.7678e-05 - accuracy: 1.0000 - val_loss: 6.5068e-05 - val_accuracy: 1.0000
#
# Epoch 00118: val_loss improved from 0.00007 to 0.00007, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 119/1000
# 5/5 [==============================] - 0s 28ms/step - loss: 7.0605e-05 - accuracy: 1.0000 - val_loss: 6.3886e-05 - val_accuracy: 1.0000
#
# Epoch 00119: val_loss improved from 0.00007 to 0.00006, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 120/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 6.1085e-05 - accuracy: 1.0000 - val_loss: 6.2742e-05 - val_accuracy: 1.0000
#
# Epoch 00120: val_loss improved from 0.00006 to 0.00006, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 121/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 6.3047e-05 - accuracy: 1.0000 - val_loss: 6.1537e-05 - val_accuracy: 1.0000
#
# Epoch 00121: val_loss improved from 0.00006 to 0.00006, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 122/1000
# 5/5 [==============================] - 0s 41ms/step - loss: 6.1089e-05 - accuracy: 1.0000 - val_loss: 6.0392e-05 - val_accuracy: 1.0000
#
# Epoch 00122: val_loss improved from 0.00006 to 0.00006, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 123/1000
# 5/5 [==============================] - 0s 17ms/step - loss: 6.2440e-05 - accuracy: 1.0000 - val_loss: 5.9221e-05 - val_accuracy: 1.0000
#
# Epoch 00123: val_loss improved from 0.00006 to 0.00006, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 124/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 5.9526e-05 - accuracy: 1.0000 - val_loss: 5.8130e-05 - val_accuracy: 1.0000
#
# Epoch 00124: val_loss improved from 0.00006 to 0.00006, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 125/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 5.9801e-05 - accuracy: 1.0000 - val_loss: 5.7103e-05 - val_accuracy: 1.0000
#
# Epoch 00125: val_loss improved from 0.00006 to 0.00006, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 126/1000
# 5/5 [==============================] - 0s 28ms/step - loss: 5.6498e-05 - accuracy: 1.0000 - val_loss: 5.6104e-05 - val_accuracy: 1.0000
#
# Epoch 00126: val_loss improved from 0.00006 to 0.00006, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 127/1000
# 5/5 [==============================] - 0s 23ms/step - loss: 5.5945e-05 - accuracy: 1.0000 - val_loss: 5.5114e-05 - val_accuracy: 1.0000
#
# Epoch 00127: val_loss improved from 0.00006 to 0.00006, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 128/1000
# 5/5 [==============================] - 0s 28ms/step - loss: 5.7268e-05 - accuracy: 1.0000 - val_loss: 5.4159e-05 - val_accuracy: 1.0000
#
# Epoch 00128: val_loss improved from 0.00006 to 0.00005, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 129/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 5.3256e-05 - accuracy: 1.0000 - val_loss: 5.3215e-05 - val_accuracy: 1.0000
#
# Epoch 00129: val_loss improved from 0.00005 to 0.00005, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 130/1000
# 5/5 [==============================] - 0s 28ms/step - loss: 5.5880e-05 - accuracy: 1.0000 - val_loss: 5.2265e-05 - val_accuracy: 1.0000
#
# Epoch 00130: val_loss improved from 0.00005 to 0.00005, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 131/1000
# 5/5 [==============================] - 0s 20ms/step - loss: 5.8590e-05 - accuracy: 1.0000 - val_loss: 5.1355e-05 - val_accuracy: 1.0000
#
# Epoch 00131: val_loss improved from 0.00005 to 0.00005, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 132/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 5.3764e-05 - accuracy: 1.0000 - val_loss: 5.0492e-05 - val_accuracy: 1.0000
#
# Epoch 00132: val_loss improved from 0.00005 to 0.00005, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 133/1000
# 5/5 [==============================] - 0s 23ms/step - loss: 5.0624e-05 - accuracy: 1.0000 - val_loss: 4.9643e-05 - val_accuracy: 1.0000
#
# Epoch 00133: val_loss improved from 0.00005 to 0.00005, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 134/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 5.3339e-05 - accuracy: 1.0000 - val_loss: 4.8815e-05 - val_accuracy: 1.0000
#
# Epoch 00134: val_loss improved from 0.00005 to 0.00005, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 135/1000
# 5/5 [==============================] - 0s 29ms/step - loss: 4.5456e-05 - accuracy: 1.0000 - val_loss: 4.8046e-05 - val_accuracy: 1.0000
#
# Epoch 00135: val_loss improved from 0.00005 to 0.00005, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 136/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 4.3571e-05 - accuracy: 1.0000 - val_loss: 4.7250e-05 - val_accuracy: 1.0000
#
# Epoch 00136: val_loss improved from 0.00005 to 0.00005, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 137/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 4.8979e-05 - accuracy: 1.0000 - val_loss: 4.6409e-05 - val_accuracy: 1.0000
#
# Epoch 00137: val_loss improved from 0.00005 to 0.00005, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 138/1000
# 5/5 [==============================] - 0s 29ms/step - loss: 4.8062e-05 - accuracy: 1.0000 - val_loss: 4.5639e-05 - val_accuracy: 1.0000
#
# Epoch 00138: val_loss improved from 0.00005 to 0.00005, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 139/1000
# 5/5 [==============================] - 0s 18ms/step - loss: 4.6187e-05 - accuracy: 1.0000 - val_loss: 4.4900e-05 - val_accuracy: 1.0000
#
# Epoch 00139: val_loss improved from 0.00005 to 0.00004, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 140/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 4.2887e-05 - accuracy: 1.0000 - val_loss: 4.4192e-05 - val_accuracy: 1.0000
#
# Epoch 00140: val_loss improved from 0.00004 to 0.00004, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 141/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 4.4096e-05 - accuracy: 1.0000 - val_loss: 4.3440e-05 - val_accuracy: 1.0000
#
# Epoch 00141: val_loss improved from 0.00004 to 0.00004, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 142/1000
# 5/5 [==============================] - 0s 23ms/step - loss: 4.6321e-05 - accuracy: 1.0000 - val_loss: 4.2737e-05 - val_accuracy: 1.0000
#
# Epoch 00142: val_loss improved from 0.00004 to 0.00004, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 143/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 4.6025e-05 - accuracy: 1.0000 - val_loss: 4.2053e-05 - val_accuracy: 1.0000
#
# Epoch 00143: val_loss improved from 0.00004 to 0.00004, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 144/1000
# 5/5 [==============================] - 0s 29ms/step - loss: 4.3538e-05 - accuracy: 1.0000 - val_loss: 4.1390e-05 - val_accuracy: 1.0000
#
# Epoch 00144: val_loss improved from 0.00004 to 0.00004, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 145/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 4.4300e-05 - accuracy: 1.0000 - val_loss: 4.0769e-05 - val_accuracy: 1.0000
#
# Epoch 00145: val_loss improved from 0.00004 to 0.00004, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 146/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 4.3159e-05 - accuracy: 1.0000 - val_loss: 4.0171e-05 - val_accuracy: 1.0000
#
# Epoch 00146: val_loss improved from 0.00004 to 0.00004, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 147/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 3.9598e-05 - accuracy: 1.0000 - val_loss: 3.9589e-05 - val_accuracy: 1.0000
#
# Epoch 00147: val_loss improved from 0.00004 to 0.00004, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 148/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 3.7667e-05 - accuracy: 1.0000 - val_loss: 3.8964e-05 - val_accuracy: 1.0000
#
# Epoch 00148: val_loss improved from 0.00004 to 0.00004, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 149/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 4.2418e-05 - accuracy: 1.0000 - val_loss: 3.8351e-05 - val_accuracy: 1.0000
#
# Epoch 00149: val_loss improved from 0.00004 to 0.00004, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 150/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 3.8740e-05 - accuracy: 1.0000 - val_loss: 3.7783e-05 - val_accuracy: 1.0000
#
# Epoch 00150: val_loss improved from 0.00004 to 0.00004, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 151/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 3.6505e-05 - accuracy: 1.0000 - val_loss: 3.7222e-05 - val_accuracy: 1.0000
#
# Epoch 00151: val_loss improved from 0.00004 to 0.00004, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 152/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 3.4842e-05 - accuracy: 1.0000 - val_loss: 3.6684e-05 - val_accuracy: 1.0000
#
# Epoch 00152: val_loss improved from 0.00004 to 0.00004, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 153/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 3.6361e-05 - accuracy: 1.0000 - val_loss: 3.6138e-05 - val_accuracy: 1.0000
#
# Epoch 00153: val_loss improved from 0.00004 to 0.00004, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 154/1000
# 5/5 [==============================] - 0s 29ms/step - loss: 3.5065e-05 - accuracy: 1.0000 - val_loss: 3.5601e-05 - val_accuracy: 1.0000
#
# Epoch 00154: val_loss improved from 0.00004 to 0.00004, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 155/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 3.4029e-05 - accuracy: 1.0000 - val_loss: 3.5067e-05 - val_accuracy: 1.0000
#
# Epoch 00155: val_loss improved from 0.00004 to 0.00004, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 156/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 3.3520e-05 - accuracy: 1.0000 - val_loss: 3.4540e-05 - val_accuracy: 1.0000
#
# Epoch 00156: val_loss improved from 0.00004 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 157/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 3.4351e-05 - accuracy: 1.0000 - val_loss: 3.4020e-05 - val_accuracy: 1.0000
#
# Epoch 00157: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 158/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 3.5743e-05 - accuracy: 1.0000 - val_loss: 3.3510e-05 - val_accuracy: 1.0000
#
# Epoch 00158: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 159/1000
# 5/5 [==============================] - 0s 23ms/step - loss: 3.1620e-05 - accuracy: 1.0000 - val_loss: 3.3003e-05 - val_accuracy: 1.0000
#
# Epoch 00159: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 160/1000
# 5/5 [==============================] - 0s 22ms/step - loss: 3.3717e-05 - accuracy: 1.0000 - val_loss: 3.2492e-05 - val_accuracy: 1.0000
#
# Epoch 00160: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 161/1000
# 5/5 [==============================] - 0s 28ms/step - loss: 3.3100e-05 - accuracy: 1.0000 - val_loss: 3.2010e-05 - val_accuracy: 1.0000
#
# Epoch 00161: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 162/1000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.4452e-05 - accuracy: 1.0000 - val_loss: 3.1534e-05 - val_accuracy: 1.0000
#
# Epoch 00162: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 163/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 3.4098e-05 - accuracy: 1.0000 - val_loss: 3.1028e-05 - val_accuracy: 1.0000
#
# Epoch 00163: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 164/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 3.1676e-05 - accuracy: 1.0000 - val_loss: 3.0571e-05 - val_accuracy: 1.0000
#
# Epoch 00164: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 165/1000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.1885e-05 - accuracy: 1.0000 - val_loss: 3.0120e-05 - val_accuracy: 1.0000
#
# Epoch 00165: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 166/1000
# 5/5 [==============================] - 0s 28ms/step - loss: 3.0197e-05 - accuracy: 1.0000 - val_loss: 2.9696e-05 - val_accuracy: 1.0000
#
# Epoch 00166: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 167/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 3.2147e-05 - accuracy: 1.0000 - val_loss: 2.9273e-05 - val_accuracy: 1.0000
#
# Epoch 00167: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 168/1000
# 5/5 [==============================] - 0s 17ms/step - loss: 2.8271e-05 - accuracy: 1.0000 - val_loss: 2.8873e-05 - val_accuracy: 1.0000
#
# Epoch 00168: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 169/1000
# 5/5 [==============================] - 0s 16ms/step - loss: 2.8068e-05 - accuracy: 1.0000 - val_loss: 2.8459e-05 - val_accuracy: 1.0000
#
# Epoch 00169: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 170/1000
# 5/5 [==============================] - 0s 18ms/step - loss: 2.9613e-05 - accuracy: 1.0000 - val_loss: 2.8060e-05 - val_accuracy: 1.0000
#
# Epoch 00170: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 171/1000
# 5/5 [==============================] - 0s 17ms/step - loss: 3.0070e-05 - accuracy: 1.0000 - val_loss: 2.7676e-05 - val_accuracy: 1.0000
#
# Epoch 00171: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 172/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 2.7689e-05 - accuracy: 1.0000 - val_loss: 2.7308e-05 - val_accuracy: 1.0000
#
# Epoch 00172: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 173/1000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.8605e-05 - accuracy: 1.0000 - val_loss: 2.6952e-05 - val_accuracy: 1.0000
#
# Epoch 00173: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 174/1000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.7346e-05 - accuracy: 1.0000 - val_loss: 2.6585e-05 - val_accuracy: 1.0000
#
# Epoch 00174: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 175/1000
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6986e-05 - accuracy: 1.0000 - val_loss: 2.6238e-05 - val_accuracy: 1.0000
#
# Epoch 00175: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 176/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 2.5833e-05 - accuracy: 1.0000 - val_loss: 2.5886e-05 - val_accuracy: 1.0000
#
# Epoch 00176: val_loss improved from 0.00003 to 0.00003, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# ...
#
# Epoch 00936: val_loss did not improve from 0.00000
# Epoch 937/1000
# 5/5 [==============================] - 0s 23ms/step - loss: 3.7940e-07 - accuracy: 1.0000 - val_loss: 4.0217e-07 - val_accuracy: 1.0000
#
# Epoch 00937: val_loss did not improve from 0.00000
# Epoch 938/1000
# 5/5 [==============================] - 0s 18ms/step - loss: 3.7107e-07 - accuracy: 1.0000 - val_loss: 3.9955e-07 - val_accuracy: 1.0000
#
# Epoch 00938: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 939/1000
# 5/5 [==============================] - 0s 20ms/step - loss: 4.1514e-07 - accuracy: 1.0000 - val_loss: 3.9693e-07 - val_accuracy: 1.0000
#
# Epoch 00939: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 940/1000
# 5/5 [==============================] - 0s 19ms/step - loss: 4.1283e-07 - accuracy: 1.0000 - val_loss: 3.9562e-07 - val_accuracy: 1.0000
#
# Epoch 00940: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 941/1000
# 5/5 [==============================] - 0s 17ms/step - loss: 4.0000e-07 - accuracy: 1.0000 - val_loss: 3.9300e-07 - val_accuracy: 1.0000
#
# Epoch 00941: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 942/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 3.5479e-07 - accuracy: 1.0000 - val_loss: 3.9169e-07 - val_accuracy: 1.0000
#
# Epoch 00942: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 943/1000
# 5/5 [==============================] - 0s 19ms/step - loss: 3.7464e-07 - accuracy: 1.0000 - val_loss: 3.8907e-07 - val_accuracy: 1.0000
#
# Epoch 00943: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 944/1000
# 5/5 [==============================] - 0s 16ms/step - loss: 3.6852e-07 - accuracy: 1.0000 - val_loss: 3.8907e-07 - val_accuracy: 1.0000
#
# Epoch 00944: val_loss did not improve from 0.00000
# Epoch 945/1000
# 5/5 [==============================] - 0s 18ms/step - loss: 3.5650e-07 - accuracy: 1.0000 - val_loss: 3.8776e-07 - val_accuracy: 1.0000
#
# Epoch 00945: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 946/1000
# 5/5 [==============================] - 0s 29ms/step - loss: 4.1410e-07 - accuracy: 1.0000 - val_loss: 3.8645e-07 - val_accuracy: 1.0000
#
# Epoch 00946: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 947/1000
# 5/5 [==============================] - 0s 19ms/step - loss: 3.7186e-07 - accuracy: 1.0000 - val_loss: 3.8514e-07 - val_accuracy: 1.0000
#
# Epoch 00947: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 948/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 3.7530e-07 - accuracy: 1.0000 - val_loss: 3.8514e-07 - val_accuracy: 1.0000
#
# Epoch 00948: val_loss did not improve from 0.00000
# Epoch 949/1000
# 5/5 [==============================] - 0s 23ms/step - loss: 3.7251e-07 - accuracy: 1.0000 - val_loss: 3.8252e-07 - val_accuracy: 1.0000
#
# Epoch 00949: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 950/1000
# 5/5 [==============================] - 0s 18ms/step - loss: 3.4515e-07 - accuracy: 1.0000 - val_loss: 3.7859e-07 - val_accuracy: 1.0000
#
# Epoch 00950: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 951/1000
# 5/5 [==============================] - 0s 15ms/step - loss: 3.6292e-07 - accuracy: 1.0000 - val_loss: 3.7597e-07 - val_accuracy: 1.0000
#
# Epoch 00951: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 952/1000
# 5/5 [==============================] - 0s 17ms/step - loss: 3.8264e-07 - accuracy: 1.0000 - val_loss: 3.7466e-07 - val_accuracy: 1.0000
#
# Epoch 00952: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 953/1000
# 5/5 [==============================] - 0s 16ms/step - loss: 3.5951e-07 - accuracy: 1.0000 - val_loss: 3.7073e-07 - val_accuracy: 1.0000
#
# Epoch 00953: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 954/1000
# 5/5 [==============================] - 0s 29ms/step - loss: 3.6993e-07 - accuracy: 1.0000 - val_loss: 3.7073e-07 - val_accuracy: 1.0000
#
# Epoch 00954: val_loss did not improve from 0.00000
# Epoch 955/1000
# 5/5 [==============================] - 0s 18ms/step - loss: 3.4053e-07 - accuracy: 1.0000 - val_loss: 3.6680e-07 - val_accuracy: 1.0000
#
# Epoch 00955: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 956/1000
# 5/5 [==============================] - 0s 30ms/step - loss: 3.5208e-07 - accuracy: 1.0000 - val_loss: 3.6549e-07 - val_accuracy: 1.0000
#
# Epoch 00956: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 957/1000
# 5/5 [==============================] - 0s 16ms/step - loss: 3.6405e-07 - accuracy: 1.0000 - val_loss: 3.6549e-07 - val_accuracy: 1.0000
#
# Epoch 00957: val_loss did not improve from 0.00000
# Epoch 958/1000
# 5/5 [==============================] - 0s 24ms/step - loss: 3.4025e-07 - accuracy: 1.0000 - val_loss: 3.6418e-07 - val_accuracy: 1.0000
#
# Epoch 00958: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 959/1000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.5277e-07 - accuracy: 1.0000 - val_loss: 3.6156e-07 - val_accuracy: 1.0000
#
# Epoch 00959: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 960/1000
# 5/5 [==============================] - 0s 17ms/step - loss: 3.3780e-07 - accuracy: 1.0000 - val_loss: 3.6156e-07 - val_accuracy: 1.0000
#
# Epoch 00960: val_loss did not improve from 0.00000
# Epoch 961/1000
# 5/5 [==============================] - 0s 18ms/step - loss: 3.6198e-07 - accuracy: 1.0000 - val_loss: 3.5894e-07 - val_accuracy: 1.0000
#
# Epoch 00961: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 962/1000
# 5/5 [==============================] - 0s 16ms/step - loss: 3.2309e-07 - accuracy: 1.0000 - val_loss: 3.5894e-07 - val_accuracy: 1.0000
#
# Epoch 00962: val_loss did not improve from 0.00000
# Epoch 963/1000
# 5/5 [==============================] - 0s 17ms/step - loss: 3.3421e-07 - accuracy: 1.0000 - val_loss: 3.5894e-07 - val_accuracy: 1.0000
#
# Epoch 00963: val_loss did not improve from 0.00000
# Epoch 964/1000
# 5/5 [==============================] - 0s 23ms/step - loss: 3.2725e-07 - accuracy: 1.0000 - val_loss: 3.5763e-07 - val_accuracy: 1.0000
#
# Epoch 00964: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 965/1000
# 5/5 [==============================] - 0s 28ms/step - loss: 3.6480e-07 - accuracy: 1.0000 - val_loss: 3.5763e-07 - val_accuracy: 1.0000
#
# Epoch 00965: val_loss did not improve from 0.00000
# Epoch 966/1000
# 5/5 [==============================] - 0s 28ms/step - loss: 3.8536e-07 - accuracy: 1.0000 - val_loss: 3.5632e-07 - val_accuracy: 1.0000
#
# Epoch 00966: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 967/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 3.3352e-07 - accuracy: 1.0000 - val_loss: 3.5501e-07 - val_accuracy: 1.0000
#
# Epoch 00967: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 968/1000
# 5/5 [==============================] - 0s 16ms/step - loss: 3.5598e-07 - accuracy: 1.0000 - val_loss: 3.5239e-07 - val_accuracy: 1.0000
#
# Epoch 00968: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 969/1000
# 5/5 [==============================] - 0s 17ms/step - loss: 3.5064e-07 - accuracy: 1.0000 - val_loss: 3.5239e-07 - val_accuracy: 1.0000
#
# Epoch 00969: val_loss did not improve from 0.00000
# Epoch 970/1000
# 5/5 [==============================] - 0s 18ms/step - loss: 3.4559e-07 - accuracy: 1.0000 - val_loss: 3.5108e-07 - val_accuracy: 1.0000
#
# Epoch 00970: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 971/1000
# 5/5 [==============================] - 0s 29ms/step - loss: 3.4129e-07 - accuracy: 1.0000 - val_loss: 3.4977e-07 - val_accuracy: 1.0000
#
# Epoch 00971: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 972/1000
# 5/5 [==============================] - 0s 17ms/step - loss: 3.1847e-07 - accuracy: 1.0000 - val_loss: 3.4846e-07 - val_accuracy: 1.0000
#
# Epoch 00972: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 973/1000
# 5/5 [==============================] - 0s 14ms/step - loss: 3.6362e-07 - accuracy: 1.0000 - val_loss: 3.4715e-07 - val_accuracy: 1.0000
#
# Epoch 00973: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 974/1000
# 5/5 [==============================] - 0s 18ms/step - loss: 3.3401e-07 - accuracy: 1.0000 - val_loss: 3.4715e-07 - val_accuracy: 1.0000
#
# Epoch 00974: val_loss did not improve from 0.00000
# Epoch 975/1000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.3438e-07 - accuracy: 1.0000 - val_loss: 3.4715e-07 - val_accuracy: 1.0000
#
# Epoch 00975: val_loss did not improve from 0.00000
# Epoch 976/1000
# 5/5 [==============================] - 0s 35ms/step - loss: 3.3455e-07 - accuracy: 1.0000 - val_loss: 3.4584e-07 - val_accuracy: 1.0000
#
# Epoch 00976: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 977/1000
# 5/5 [==============================] - 0s 18ms/step - loss: 3.4147e-07 - accuracy: 1.0000 - val_loss: 3.4584e-07 - val_accuracy: 1.0000
#
# Epoch 00977: val_loss did not improve from 0.00000
# Epoch 978/1000
# 5/5 [==============================] - 0s 16ms/step - loss: 3.3585e-07 - accuracy: 1.0000 - val_loss: 3.4453e-07 - val_accuracy: 1.0000
#
# Epoch 00978: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 979/1000
# 5/5 [==============================] - 0s 23ms/step - loss: 3.0629e-07 - accuracy: 1.0000 - val_loss: 3.4322e-07 - val_accuracy: 1.0000
#
# Epoch 00979: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 980/1000
# 5/5 [==============================] - 0s 20ms/step - loss: 2.9920e-07 - accuracy: 1.0000 - val_loss: 3.4322e-07 - val_accuracy: 1.0000
#
# Epoch 00980: val_loss did not improve from 0.00000
# Epoch 981/1000
# 5/5 [==============================] - 0s 15ms/step - loss: 3.3484e-07 - accuracy: 1.0000 - val_loss: 3.4191e-07 - val_accuracy: 1.0000
#
# Epoch 00981: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 982/1000
# 5/5 [==============================] - 0s 27ms/step - loss: 3.3639e-07 - accuracy: 1.0000 - val_loss: 3.4060e-07 - val_accuracy: 1.0000
#
# Epoch 00982: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 983/1000
# 5/5 [==============================] - 0s 29ms/step - loss: 3.2522e-07 - accuracy: 1.0000 - val_loss: 3.4060e-07 - val_accuracy: 1.0000
#
# Epoch 00983: val_loss did not improve from 0.00000
# Epoch 984/1000
# 5/5 [==============================] - 0s 18ms/step - loss: 3.2409e-07 - accuracy: 1.0000 - val_loss: 3.4060e-07 - val_accuracy: 1.0000
#
# Epoch 00984: val_loss did not improve from 0.00000
# Epoch 985/1000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.8781e-07 - accuracy: 1.0000 - val_loss: 3.3929e-07 - val_accuracy: 1.0000
#
# Epoch 00985: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 986/1000
# 5/5 [==============================] - 0s 18ms/step - loss: 3.0498e-07 - accuracy: 1.0000 - val_loss: 3.3929e-07 - val_accuracy: 1.0000
#
# Epoch 00986: val_loss did not improve from 0.00000
# Epoch 987/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 3.1240e-07 - accuracy: 1.0000 - val_loss: 3.3667e-07 - val_accuracy: 1.0000
#
# Epoch 00987: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 988/1000
# 5/5 [==============================] - 0s 20ms/step - loss: 3.1694e-07 - accuracy: 1.0000 - val_loss: 3.3667e-07 - val_accuracy: 1.0000
#
# Epoch 00988: val_loss did not improve from 0.00000
# Epoch 989/1000
# 5/5 [==============================] - 0s 21ms/step - loss: 3.0697e-07 - accuracy: 1.0000 - val_loss: 3.3667e-07 - val_accuracy: 1.0000
#
# Epoch 00989: val_loss did not improve from 0.00000
# Epoch 990/1000
# 5/5 [==============================] - 0s 28ms/step - loss: 3.1084e-07 - accuracy: 1.0000 - val_loss: 3.3536e-07 - val_accuracy: 1.0000
#
# Epoch 00990: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 991/1000
# 5/5 [==============================] - 0s 19ms/step - loss: 2.9849e-07 - accuracy: 1.0000 - val_loss: 3.3405e-07 - val_accuracy: 1.0000
#
# Epoch 00991: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 992/1000
# 5/5 [==============================] - 0s 17ms/step - loss: 3.3622e-07 - accuracy: 1.0000 - val_loss: 3.3274e-07 - val_accuracy: 1.0000
#
# Epoch 00992: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 993/1000
# 5/5 [==============================] - 0s 29ms/step - loss: 3.1220e-07 - accuracy: 1.0000 - val_loss: 3.3012e-07 - val_accuracy: 1.0000
#
# Epoch 00993: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 994/1000
# 5/5 [==============================] - 0s 16ms/step - loss: 3.1608e-07 - accuracy: 1.0000 - val_loss: 3.2881e-07 - val_accuracy: 1.0000
#
# Epoch 00994: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 995/1000
# 5/5 [==============================] - 0s 15ms/step - loss: 3.2730e-07 - accuracy: 1.0000 - val_loss: 3.2881e-07 - val_accuracy: 1.0000
#
# Epoch 00995: val_loss did not improve from 0.00000
# Epoch 996/1000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9464e-07 - accuracy: 1.0000 - val_loss: 3.2750e-07 - val_accuracy: 1.0000
#
# Epoch 00996: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5
# Epoch 997/1000
# 5/5 [==============================] - 0s 21ms/step - loss: 2.9487e-07 - accuracy: 1.0000 - val_loss: 3.2750e-07 - val_accuracy: 1.0000
#
# Epoch 00997: val_loss did not improve from 0.00000
# Epoch 998/1000
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7293e-07 - accuracy: 1.0000 - val_loss: 3.2750e-07 - val_accuracy: 1.0000
#
# Epoch 00998: val_loss did not improve from 0.00000
# Epoch 999/1000
# 5/5 [==============================] - 0s 25ms/step - loss: 3.0653e-07 - accuracy: 1.0000 - val_loss: 3.2750e-07 - val_accuracy: 1.0000
#
# Epoch 00999: val_loss did not improve from 0.00000
# Epoch 1000/1000
# 5/5 [==============================] - 0s 16ms/step - loss: 2.9994e-07 - accuracy: 1.0000 - val_loss: 3.2619e-07 - val_accuracy: 1.0000
#
# Epoch 01000: val_loss improved from 0.00000 to 0.00000, saving model to model/keypoint_classifier\keypoint_classifier.hdf5

# %%
# Loading the saved model
model = tf.keras.models.load_model(model_save_path)

# %%
# Model evaluation
# TODO Test on loaded model
val_loss, val_acc = model.evaluate(X_test, y_test, batch_size=64)
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 3.2619e-07 - accuracy: 1.0000

# %%
# Inference test
predict_result = model.predict(np.array([X_test[0]]))
print(np.squeeze(predict_result))
print(np.argmax(np.squeeze(predict_result)))
# Out:
# [9.999993e-01 7.466420e-07]
# 0

# %% [markdown]
# # Confusion matrix

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def print_confusion_matrix(y_true, y_pred, report=True):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)
 
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(df_cmx, annot=True, fmt='g' ,square=False)
    ax.set_ylim(len(set(y_true)), 0)
    plt.show()
    
    if report:
        print('Classification Report')
        print(classification_report(y_test, y_pred))

Y_pred = model.predict(X_test)
y_pred = np.argmax(Y_pred, axis=1)

print_confusion_matrix(y_test, y_pred)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        52
#            1       1.00      1.00      1.00        39
#
#     accuracy                           1.00        91
#    macro avg       1.00      1.00      1.00        91
# weighted avg       1.00      1.00      1.00        91

# %% [markdown]
# # Convert to model for Tensorflow-Lite

# %%
# Save as a model dedicated to inference
model.save(model_save_path, include_optimizer=False)

# %%
# Transform model (quantization)

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quantized_model = converter.convert()

open(tflite_save_path, 'wb').write(tflite_quantized_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\qianlai\AppData\Local\Temp\tmpii1xnji0\assets
# 7296

# %% [markdown]
# ## Inference test

# %%
interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()

# %%
# Get I / O tensor
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
interpreter.set_tensor(input_details[0]['index'], np.array([X_test[0]]))

# %%
# %%time
# Inference implementation
interpreter.invoke()
tflite_results = interpreter.get_tensor(output_details[0]['index'])
# Out:
# Wall time: 0 ns

# %%
print(np.squeeze(tflite_results))
print(np.argmax(np.squeeze(tflite_results)))
# Out:
# [9.9999928e-01 7.2498403e-07]
# 0
